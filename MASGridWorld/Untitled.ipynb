# %%
import matplotlib.pyplot as plt
import pandas as pd
import pickle

# %%
# Load metrics
with open("Models/metrics.pkl", "rb") as f:
    metrics = pickle.load(f)
    metrics = pd.DataFrame(metrics["reward"])
    
    display(metrics.describe())
# Out:
#        Simulation No.  Avg Cumulative Reward  Global Capture Reward  \
# count     1250.000000            1250.000000            1250.000000
# mean       624.500000               1.670374               0.612800
# std        360.988227               0.233472               1.205337
# min          0.000000               1.027083               0.000000
# 25%        312.250000               1.490521               0.000000
# 50%        624.500000               1.685833               0.000000
# 75%        936.750000               1.842188               1.000000
# max       1249.000000               2.450000               5.000000
#
#        Local Capture Reward  Reachability Reward
# count                1250.0          1250.000000
# mean                    0.0             3.317026
# std                     0.0             0.443844
# min                     0.0             2.054167
# 25%                     0.0             2.973542
# 50%                     0.0             3.347917
# ...

# %%
plt
